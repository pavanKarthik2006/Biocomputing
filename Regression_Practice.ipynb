# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanKarthik2006/Biocomputing/blob/main/Regression_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing

# %%
data=fetch_california_housing()

# %%
data.data.shape
# Out:
# (20640, 8)

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)
missing_values=df.isnull().sum().sum()

# %%
from sklearn.model_selection import train_test_split

X=pd.DataFrame(data.data,columns=data.feature_names)
y=data.target
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0,shuffle=False)

# %%
house_age_value=X_test.iloc[2]['HouseAge']
print(house_age_value)
# Out:
# 28.0

# %%
population_value=X_train.iloc[1]['Population']
print(population_value)
# Out:
# 2401.0

# %%
train_average=y_train.mean()
print(train_average)
# Out:
# 2.02067031310562

# %%
median_test=np.median(y_test)
print(median_test)
# Out:
# 2.1475

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)

model=LinearRegression()
model.fit(X_train_scaled,y_train)

coefficients=pd.Series(model.coef_)
print(coefficients)
# Out:
# 0    0.838180
# 1    0.120321
# 2   -0.321358
# 3    0.364566
# 4   -0.001707
# 5   -0.045246
# 6   -0.879942
# 7   -0.826341
# dtype: float64

# %%
bias=pd.Series(model.intercept_)
print(bias)
# Out:
# 0    2.02067
# dtype: float64

# %%
import numpy as np

def compute_explained_variance(y_true,y_pred):
  y_true=np.array(y_true)
  y_pred=np.array(y_pred)
  numerator=np.var(y_true-y_pred)
  denominator=np.var(y_pred)
  return 1-(numerator/denominator)


y_true = [7, 4, 9, 4]
y_pred = [8, 7, 12, 5]
score=compute_explained_variance(y_true,y_pred)
print(score)
# Out:
# 0.8461538461538461

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn.datasets import fetch_california_housing

def compute_score(X_train,X_test,y_train,y_test):
  scaler=StandardScaler(with_mean=True, with_std=True)

  X_train_norm=scaler.fit_transform(X_train)
  X_test_norm=scaler.fit_transform(X_test)

  model=SGDRegressor(loss='squared_error',penalty='l1',alpha=0.01,random_state=1)
  model.fit(X_train_norm,y_train)
  return model.score(X_test_norm,y_test)

data=fetch_california_housing()
X=data.data
y=data.target

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

score=compute_score(X_train,X_test,y_train,y_test)
print(score)
# Out:
# 0.6187330221933827
