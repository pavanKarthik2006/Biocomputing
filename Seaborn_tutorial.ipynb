# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanKarthik2006/Biocomputing/blob/main/Seaborn_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seaborn Tutorial

# %%
import pandas as pd
import seaborn as sns
from copy import deepcopy

# %%
#reading the  data
Data=pd.read_csv('/content/train.csv')

# %%
# Extracting the columns
exploration_set=deepcopy(Data[['ID','RecipeNumber','RecipeCode','UserReputation','ThumbsUpCount', 'ThumbsDownCount','BestScore','Rating']])

# Creating a correlation matrix
corr_matrix=exploration_set.corr(method='pearson')

# Creating  a heatmap
sns.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=Data['RecipeNumber'],y=Data['RecipeCode'], hue=Data['Rating'])
# Out:
# <Axes: xlabel='RecipeNumber', ylabel='RecipeCode'>

# %%
sns.scatterplot(x=Data['ThumbsUpCount'],y=Data['BestScore'], hue=Data['Rating'])
# Out:
# <Axes: xlabel='ThumbsUpCount', ylabel='BestScore'>

# %%
Data.hist(bins=50,figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'ID'}>,
#         <Axes: title={'center': 'RecipeNumber'}>,
#         <Axes: title={'center': 'RecipeCode'}>],
#        [<Axes: title={'center': 'UserReputation'}>,
#         <Axes: title={'center': 'CreationTimestamp'}>,
#         <Axes: title={'center': 'ReplyCount'}>],
#        [<Axes: title={'center': 'ThumbsUpCount'}>,
#         <Axes: title={'center': 'ThumbsDownCount'}>,
#         <Axes: title={'center': 'Rating'}>],
#        [<Axes: title={'center': 'BestScore'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.pairplot(Data, diag_kind="hist")
